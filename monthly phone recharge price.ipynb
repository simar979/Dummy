# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\simar\Downloads\phone_usage_india.csv")
df
#goal to predict users Monthly Recharge Cost
# Out:
#       User ID  Age  Gender   Location Phone Brand       OS  \
# 0      U00001   53    Male     Mumbai        Vivo  Android
# 1      U00002   60   Other      Delhi      Realme      iOS
# 2      U00003   37  Female  Ahmedabad       Nokia  Android
# 3      U00004   32    Male       Pune     Samsung  Android
# 4      U00005   16    Male     Mumbai      Xiaomi      iOS
# ...       ...  ...     ...        ...         ...      ...
# 17681  U17682   27   Other     Mumbai       Apple      iOS
# 17682  U17683   40  Female    Chennai        Oppo      iOS
# 17683  U17684   34  Female  Ahmedabad      Realme  Android
# 17684  U17685   22    Male  Hyderabad        Vivo  Android
# 17685  U17686   43   Other    Kolkata        Oppo      iOS
#
#        Screen Time (hrs/day)  Data Usage (GB/month)  \
# 0                        3.7                   23.9
# 1                        9.2                   28.1
# 2                        4.5                   12.3
# ...

# %%
df1=df.drop(["User ID","Location","OS"],axis=1)
df1
# Out:
#        Age  Gender Phone Brand  Screen Time (hrs/day)  Data Usage (GB/month)  \
# 0       53    Male        Vivo                    3.7                   23.9
# 1       60   Other      Realme                    9.2                   28.1
# 2       37  Female       Nokia                    4.5                   12.3
# 3       32    Male     Samsung                   11.0                   25.6
# 4       16    Male      Xiaomi                    2.2                    2.5
# ...    ...     ...         ...                    ...                    ...
# 17681   27   Other       Apple                    7.2                   36.6
# 17682   40  Female        Oppo                    9.5                   12.9
# 17683   34  Female      Realme                    1.1                   48.9
# 17684   22    Male        Vivo                    8.8                   25.6
# 17685   43   Other        Oppo                    5.6                   22.5
#
# ...

# %%
print(df1.isna().sum())
# Out:
# Age                             0
# Gender                          0
# Phone Brand                     0
# Screen Time (hrs/day)           0
# Data Usage (GB/month)           0
# Calls Duration (mins/day)       0
# Number of Apps Installed        0
# Social Media Time (hrs/day)     0
# E-commerce Spend (INR/month)    0
# Streaming Time (hrs/day)        0
# Gaming Time (hrs/day)           0
# Monthly Recharge Cost (INR)     0
# Primary Use                     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17686 entries, 0 to 17685
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           17686 non-null  int64
#  1   Gender                        17686 non-null  object
#  2   Phone Brand                   17686 non-null  object
#  3   Screen Time (hrs/day)         17686 non-null  float64
#  4   Data Usage (GB/month)         17686 non-null  float64
#  5   Calls Duration (mins/day)     17686 non-null  float64
#  6   Number of Apps Installed      17686 non-null  int64
#  7   Social Media Time (hrs/day)   17686 non-null  float64
#  8   E-commerce Spend (INR/month)  17686 non-null  int64
#  9   Streaming Time (hrs/day)      17686 non-null  float64
#  10  Gaming Time (hrs/day)         17686 non-null  float64
#  11  Monthly Recharge Cost (INR)   17686 non-null  int64
# ...

# %%
df1.columns
# Out:
# Index(['Age', 'Gender', 'Phone Brand', 'Screen Time (hrs/day)',
#        'Data Usage (GB/month)', 'Calls Duration (mins/day)',
#        'Number of Apps Installed', 'Social Media Time (hrs/day)',
#        'E-commerce Spend (INR/month)', 'Streaming Time (hrs/day)',
#        'Gaming Time (hrs/day)', 'Monthly Recharge Cost (INR)', 'Primary Use'],
#       dtype='object')

# %%
#primary usage
print(df1["Primary Use"].value_counts())
# Out:
# Primary Use
# Education        3601
# Gaming           3576
# Work             3557
# Social Media     3501
# Entertainment    3451
# Name: count, dtype: int64

# %%
#we will apply one hot encoding on it

# %%
print(df1["Monthly Recharge Cost (INR)"].value_counts())
# Out:
# Monthly Recharge Cost (INR)
# 921     24
# 1939    20
# 258     20
# 953     20
# 316     19
#         ..
# 1717     2
# 606      2
# 1447     2
# 1421     2
# 1187     1
# Name: count, Length: 1901, dtype: int64

# %%
print(df1["Gaming Time (hrs/day)"].value_counts())
# Out:
# Gaming Time (hrs/day)
# 1.2    392
# 4.9    385
# 3.0    381
# 2.7    378
# 4.5    373
# 2.9    372
# 3.6    372
# 1.4    372
# 3.8    371
# 0.7    370
# 0.2    369
# 0.9    368
# 0.4    368
# 4.3    365
# 0.3    365
# 2.4    363
# 4.7    361
# 3.1    361
# 1.7    361
# 4.6    357
# 3.7    357
# 1.5    356
# 1.3    356
# 3.3    354
# 3.9    354
# 1.8    353
# 2.2    353
# 1.0    353
# 3.4    352
# 0.1    349
# 0.8    349
# 3.5    349
# 1.6    348
# 1.9    346
# 2.5    346
# 0.6    344
# 2.3    344
# 2.8    340
# 1.1    337
# 4.0    336
# 2.0    335
# 2.6    334
# 4.1    334
# 2.1    331
# 0.5    326
# 3.2    325
# 4.4    323
# 4.2    318
# 4.8    311
# 0.0    187
# 5.0    182
# Name: count, dtype: int64

# %%
print(df1["Streaming Time (hrs/day)"].value_counts())
# Out:
# Streaming Time (hrs/day)
# 3.8    270
# 7.7    268
# 3.9    265
# 3.2    265
# 7.0    263
#       ...
# 1.1    211
# 6.6    206
# 5.2    203
# 8.0    119
# 0.5    109
# Name: count, Length: 76, dtype: int64

# %%
print(df1["E-commerce Spend (INR/month)"].value_counts())
# Out:
# E-commerce Spend (INR/month)
# 6770    9
# 8012    8
# 8996    8
# 8148    8
# 9884    8
#        ..
# 2012    1
# 6665    1
# 9236    1
# 5676    1
# 5332    1
# Name: count, Length: 8202, dtype: int64

# %%
print(df1["Social Media Time (hrs/day)"].value_counts())
# Out:
# Social Media Time (hrs/day)
# 3.7    356
# 4.9    349
# 2.1    348
# 2.0    348
# 0.7    347
# 5.9    341
# 1.7    340
# 4.4    340
# 4.8    337
# 5.6    337
# 2.9    336
# 2.7    333
# 2.8    332
# 4.2    332
# 3.3    332
# 2.6    331
# 1.1    331
# 1.3    331
# 3.6    330
# 2.3    330
# 5.0    330
# 4.6    328
# 5.3    327
# 5.7    327
# 3.8    327
# 3.9    326
# 5.2    326
# 2.2    323
# 2.5    323
# 1.2    320
# 2.4    320
# 3.2    318
# 1.0    318
# 5.8    315
# 0.9    313
# 5.1    312
# 1.8    311
# 4.1    311
# 5.5    309
# 0.8    309
# 1.6    308
# 3.0    308
# 4.5    308
# 1.4    308
# 0.6    307
# 4.3    302
# 4.0    301
# 3.1    301
# 5.4    298
# 3.4    297
# 1.9    295
# 1.5    288
# 3.5    287
# 4.7    285
# 0.5    174
# 6.0    165
# Name: count, dtype: int64

# %%
print(df1["Number of Apps Installed"].value_counts())
# Out:
# Number of Apps Installed
# 135    132
# 140    117
# 43     111
# 19     111
# 87     111
#       ...
# 33      76
# 28      73
# 112     72
# 197     70
# 41      69
# Name: count, Length: 191, dtype: int64

# %%
print(df1["Calls Duration (mins/day)"].value_counts())
# Out:
# Calls Duration (mins/day)
# 72.0     15
# 38.1     14
# 210.8    14
# 190.0    14
# 207.3    14
#          ..
# 293.3     1
# 76.2      1
# 248.7     1
# 145.3     1
# 272.3     1
# Name: count, Length: 2945, dtype: int64

# %%
print(df1["Data Usage (GB/month)"].value_counts())
# Out:
# Data Usage (GB/month)
# 4.8     57
# 2.1     57
# 15.8    57
# 33.6    53
# 22.2    52
#         ..
# 43.0    21
# 20.1    20
# 23.1    19
# 50.0    16
# 1.0     16
# Name: count, Length: 491, dtype: int64

# %%
print(df1["Screen Time (hrs/day)"].value_counts())
# Out:
# Screen Time (hrs/day)
# 4.8     191
# 9.3     190
# 8.0     189
# 7.5     188
# 8.7     186
#        ...
# 6.2     132
# 5.1     131
# 2.8     124
# 12.0     86
# 1.0      69
# Name: count, Length: 111, dtype: int64

# %%
print(df1["Phone Brand"].value_counts())
# Out:
# Phone Brand
# Nokia           1816
# OnePlus         1807
# Xiaomi          1803
# Vivo            1797
# Apple           1775
# Samsung         1764
# Realme          1762
# Google Pixel    1729
# Motorola        1717
# Oppo            1716
# Name: count, dtype: int64

# %%
#we will apply one hot encoding on it

# %%
print(df1["Age"].value_counts())
# Out:
# Age
# 58    438
# 54    423
# 19    418
# 36    411
# 46    410
# 50    407
# 47    403
# 22    402
# 40    401
# 16    400
# 28    397
# 52    397
# 24    396
# 15    396
# 48    392
# 41    390
# 35    390
# 59    390
# 21    388
# 57    387
# 30    386
# 25    385
# 56    385
# 51    383
# 37    379
# 39    378
# 49    378
# 55    377
# 23    376
# 34    375
# 31    375
# 53    375
# 44    375
# 33    374
# 26    371
# 20    370
# 17    368
# 32    367
# 45    366
# 29    365
# 27    365
# 60    359
# 18    359
# 42    356
# 38    356
# 43    347
# Name: count, dtype: int64

# %%
print(df1["Gender"].value_counts())
# Out:
# Gender
# Female    5969
# Other     5892
# Male      5825
# Name: count, dtype: int64

# %%
#we will apply one hot encoding on it

# %%
import matplotlib.pyplot as plt
plt.pie(df1["Primary Use"].value_counts(),labels=df1["Primary Use"].value_counts().index,autopct="%1.2f%%")
plt.title("Pie chart of Primary Use")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(df1["Phone Brand"].value_counts(),labels=df1["Phone Brand"].value_counts().index,autopct="%1.2f%%")
plt.title("Pie chart of Phone Brand")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(df1["Gender"].value_counts(),labels=df1["Gender"].value_counts().index,autopct="%1.2f%%")
plt.title("Pie chart of Gender")
plt.show()

# %%
#label encoding on the categorical columns,replacing categorical valus with numerical values
#prepare categorical data for machine learning

# %%
df1["Gender"]=df1["Gender"].replace({"Female":0,"Male":1,"Other":2})
df1["Phone Brand"]=df1["Phone Brand"].replace({"Nokia":0 ,"OnePlus":1,"Xiaomi":2,"Vivo":3,"Apple":4,"Samsung":5,"Realme":6,"Google Pixel":7,
    "Motorola":8,"Oppo":9})          
df1["Primary Use"]=df1["Primary Use"].replace({"Education":0,"Gaming":1,"Work":2,"Social Media":3,"Entertainment":4})
# Out:
# C:\Users\simar\AppData\Local\Temp\ipykernel_24288\3360688505.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["Gender"]=df1["Gender"].replace({"Female":0,"Male":1,"Other":2})
# C:\Users\simar\AppData\Local\Temp\ipykernel_24288\3360688505.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["Phone Brand"]=df1["Phone Brand"].replace({"Nokia":0 ,"OnePlus":1,"Xiaomi":2,"Vivo":3,"Apple":4,"Samsung":5,"Realme":6,"Google Pixel":7,
# ...

# %%
df1
# Out:
#        Age  Gender  Phone Brand  Screen Time (hrs/day)  Data Usage (GB/month)  \
# 0       53       1            3                    3.7                   23.9
# 1       60       2            6                    9.2                   28.1
# 2       37       0            0                    4.5                   12.3
# 3       32       1            5                   11.0                   25.6
# 4       16       1            2                    2.2                    2.5
# ...    ...     ...          ...                    ...                    ...
# 17681   27       2            4                    7.2                   36.6
# 17682   40       0            9                    9.5                   12.9
# 17683   34       0            6                    1.1                   48.9
# 17684   22       1            3                    8.8                   25.6
# 17685   43       2            9                    5.6                   22.5
#
# ...

# %%
x=df1.drop(columns="Monthly Recharge Cost (INR)")
y=df1["Monthly Recharge Cost (INR)"]

# %%
x
# Out:
#        Age  Gender  Phone Brand  Screen Time (hrs/day)  Data Usage (GB/month)  \
# 0       53       1            3                    3.7                   23.9
# 1       60       2            6                    9.2                   28.1
# 2       37       0            0                    4.5                   12.3
# 3       32       1            5                   11.0                   25.6
# 4       16       1            2                    2.2                    2.5
# ...    ...     ...          ...                    ...                    ...
# 17681   27       2            4                    7.2                   36.6
# 17682   40       0            9                    9.5                   12.9
# 17683   34       0            6                    1.1                   48.9
# 17684   22       1            3                    8.8                   25.6
# 17685   43       2            9                    5.6                   22.5
#
# ...

# %%
y
# Out:
# 0         803
# 1        1526
# 2        1619
# 3        1560
# 4         742
#          ...
# 17681    1380
# 17682     222
# 17683    1612
# 17684    1528
# 17685    1098
# Name: Monthly Recharge Cost (INR), Length: 17686, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data=scaler.fit_transform(x)

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
#x_train
#print(y_train,y_test)

# %%
from sklearn.linear_model import LinearRegression
a=LinearRegression()
a.fit(x_train,y_train)
y_pred=a.predict(x_test)

# %%
input_data=[[53	,1	,3	,3.7,	23.9,	37.9,	104,	3.9,	469,	5.2,	4.1	,0]] #array form
prediction=a.predict(input_data)
print("users Monthly Recharge Cost:",prediction)
# Out:
# users Monthly Recharge Cost: [1033.3753267]
# C:\Users\simar\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
